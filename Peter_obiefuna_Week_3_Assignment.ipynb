# %% [markdown]
# <a href="https://colab.research.google.com/github/Pete-Reseacher/python-geoscience/blob/main/Peter_obiefuna_Week_3_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Week 3 Assessment:

# %% [markdown]
# <pre>
# You have been handed a new well (Well_A). The company is deciding whether to invest in a multi-million-dollar completion. Your job is to provide the "Low Side”, and "High Side" estimates of the reservoir's potential.
#
# Task 1:
# In your Jupyter Notebook, load the Well_A.las file and perform the following:
# •	Identify the NULL value in the LAS header.
# •	Replace all occurrences of that NULL value in the DataFrame with np.nan.
#
# Task 2:
# Instead of using a fixed 60 API cutoff, create a Histogram of the Gamma Ray (GR_NM).
# •	Use np.percentile to find the 20th percentile and the 50th percentile of the GR data. (Check online on how to use this method)
# •	Label these as "Conservative Cutoff" and "Base Case Cutoff."
# •	Look at the "valley" between your sand and shale peaks on the histogram. Does your 50th percentile (Base Case) sit exactly in that valley? If not, what does that tell you about the proportion of sand in this well?
#
# Task 3:
# Calculate the Reservoir Quality Index (RQI) using the formula from class:
# RQI = Porosity * (1 – GR_Normalized)
# •	Create a 2-track plot: Track 1 showing Gamma Ray with your two cutoff lines, and Track 2 showing the RQI filled with a gold color.
# •	Find a zone where the Gamma Ray is low (looks like sand) but the RQI is also low. Based on your logs, why is the rock quality poor there even though it is "clean" sand? (Hint: Check the Porosity track).
#
# Task 4:
# Calculate the Net Pay thickness twice:
# 1.	Case A (Conservative): GR < 20th percentile AND Porosity > 18%.
# 2.	Case B (Optimistic): GR < 50th percentile AND Porosity > 12%.
#     Compare the two Net Pay results and write a brief report.
#
# </pre>
